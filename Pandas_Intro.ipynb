# %%
import numpy as np

# %%
import pandas as pd

# %%
grades = {"Eylul": 100, "Jane": 80,"Ela": 70}

# %%
pd.Series(grades)
# Out:
# Eylul    100
# Jane      80
# Ela       70
# dtype: int64

# %%
names = ["Eylul","Jane","Ela"]
grade = [100,80,70]

# %%
pd.Series(data = grades, index = names)
# Out:
# Eylul    100
# Jane      80
# Ela       70
# dtype: int64

# %%
# help(pd.Series()) # normally it wants data first

# %%
numpy_array = np.array([100,80,70]) # indexes automatically

# %%
pd.Series(numpy_array)
# Out:
# 0    100
# 1     80
# 2     70
# dtype: int64

# %%
# arithetmetic

# %%
contest_result = pd.Series(data = [10,5,100], index = ["Eylul","Ali","Lara"])

# %%
contest_result2 = pd.Series(data = [20,50,10], index = ["Eylul","Ali","Lara"])

# %%
contest_result["Eylul"]
# Out:
# np.int64(10)

# %%
final_result = contest_result + contest_result2
final_result
# Out:
# Eylul     30
# Ali       55
# Lara     110
# dtype: int64

# %%
contest_result / contest_result2
# Out:
# Eylul     0.5
# Ali       0.1
# Lara     10.0
# dtype: float64

# %%
# data and indexes must be in []

# %%
different_series = pd.Series(data = [1,2,3,4], index = ["a","b","c","d"])

# %%
different_series2 = pd.Series(data = [10,20,30,40], index = ["a","c","g","d"])

# %%
different_series + different_series2
# Out:
# a    11.0
# b     NaN
# c    23.0
# d    44.0
# g     NaN
# dtype: float64
